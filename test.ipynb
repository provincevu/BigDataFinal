# %%
import pandas as pd

# %%
data = pd.read_csv('data/online_retail.csv')

# %%
pd.isnull(data).sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
# xác định 1 vài dữ liệu bị null customerID
data[data['CustomerID'].isnull()].head()
# Out:
#      InvoiceNo StockCode                      Description  Quantity  \
# 622     536414     22139                              NaN        56
# 1443    536544     21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444    536544     21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445    536544     21786               POLKADOT RAIN HAT          4
# 1446    536544     21787            RAIN PONCHO RETROSPOT         2
#
#               InvoiceDate  UnitPrice  CustomerID         Country
# 622   2010-12-01 11:52:00       0.00         NaN  United Kingdom
# 1443  2010-12-01 14:32:00       2.51         NaN  United Kingdom
# 1444  2010-12-01 14:32:00       2.51         NaN  United Kingdom
# 1445  2010-12-01 14:32:00       0.85         NaN  United Kingdom
# 1446  2010-12-01 14:32:00       1.66         NaN  United Kingdom

# %%
# đếm số lượng dữ liệu có quantity < 0
data[data['Quantity'] < 0].shape[0]
# Out:
# 10624

# %%
data[data['UnitPrice'] < 0].shape[0]
# Out:
# 2

# %%
data[data['InvoiceNo'].str.startswith('C')].shape[0]
# Out:
# 9288
